# %%
import os, argparse, datetime, time, wget, json
import re
import pandas as pd
import sentencepiece as spm
from tqdm.notebook import tqdm
from tqdm import trange

# %% [markdown]
# # 학습데이터
# ## 한국 위키피디아
# ### 한국 위키피디아 csv 파일 다운로드
# * 위키파싱은 wikiextractor의 WikiExtractor.py를 사용 했습니다.

# %%
SEPARATOR = u"\u241D"


""" wiki file 목록을 읽어들임 """
def list_wiki(dirname):
    filepaths = []
    filenames = os.listdir(dirname)
    for filename in filenames:
        filepath = os.path.join(dirname, filename)

        if os.path.isdir(filepath):
            filepaths.extend(list_wiki(filepath))
        else:
            find = re.findall(r"wiki_[0-9][0-9]", filepath)
            if 0 < len(find):
                filepaths.append(filepath)
    return sorted(filepaths)


""" 여러줄띄기(\n\n...) 한줄띄기로(\n) 변경 """
def trim_text(line):
    try:
        data = json.loads(line)
        text = data["text"]
        value = list(filter(lambda x: len(x) > 0, text.split('\n')))
        data["text"] = "\n".join(value)
        return data
    except:
        return None


""" csv 파일을 제외한 나머지 파일 삭제 """
def del_garbage(dirname):
    filenames = os.listdir(dirname)
    for filename in filenames:
        filepath = os.path.join(dirname, filename)

        if os.path.isdir(filepath):
            del_garbage(filepath)
            os.rmdir(filepath)
        else:
            if not filename.endswith(".csv"):
                os.remove(filepath)

# %%
args_output = 'kowiki'

# wiki를 저장할 폴더 생성
if not os.path.isdir(args_output):
    os.makedirs(args_output)
        
filename = wget.download("https://dumps.wikimedia.org/kowiki/latest/kowiki-latest-pages-meta-current.xml.bz2", args_output)
os.system(f"python WikiExtractor.py -o {args_output} --json {filename}")

# text 여러줄 띄기를 한줄 띄기로 합침
dataset = []
filenames = list_wiki(args_output)
for filename in filenames:
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                text_line = trim_text(line)
                if text_line is not None:
                    dataset.append(text_line)
    
# 자장파일 결정
now = datetime.datetime.now().strftime("%Y%m%d")
output = f"{args_output}/kowiki_{now}.csv"

# 위키저장 (csv)
if 0 < len(dataset):
    df = pd.DataFrame(data=dataset)
    df.to_csv(output, sep=SEPARATOR, index=False)
    
# 파일삭제
del_garbage(args_output)

# %% [markdown]
# # SentencePiece
# ## SentencePiece Base Model
# ### 위키 데이터 포맷팅
# * 한국 위키데이터 csv 파일을 학습에 사용 할 수 있도록 포맷팅 및 txt 파일로 변환

# %%
in_file = "./Data/kowiki_20200715.csv"
out_file = "./Data/kowiki.txt"
SEPARATOR = u"\u241D"
df = pd.read_csv(in_file, sep=SEPARATOR, engine="python")
with open(out_file, "w") as f:
  for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    f.write(row["text"]) # title 과 text를 중복 되므로 text만 저장 함
    f.write("\n\n\n\n") # 구분자
len(df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=502158.0), HTML(value='')))
# 502158

# %% [markdown]
# ### SentencePiece 학습
# * 학습 데이터로 포맷팅 된 txt 파일은 sentencePiece 학습에 사용되며, prefix는 kowiki_30000, vocab_size는 30,000으로 임의 설정

# %%
corpus = "./Data/kowiki.txt"
prefix = "kowiki_30000"
vocab_size = 30000
# prefix = "kowiki_50000"
# vocab_size = 50000
# prefix = "kowiki_100000"
# vocab_size = 100000
spm.SentencePieceTrainer.train(
    f"--input={corpus} --model_prefix={prefix} --vocab_size={vocab_size + 7}" + 
    " --model_type=bpe" +
    " --max_sentence_length=999999" + # 문장 최대 길이
    " --pad_id=0 --pad_piece=[PAD]" + # pad (0)
    " --unk_id=1 --unk_piece=[UNK]" + # unknown (1)
    " --bos_id=2 --bos_piece=[BOS]" + # begin of sequence (2)
    " --eos_id=3 --eos_piece=[EOS]" + # end of sequence (3)
    " --user_defined_symbols=[SEP],[CLS],[MASK]") # 사용자 정의 토큰

# %% [markdown]
# ### SentencePiece Base Model Test
# * 학습된 kowiki_30000.model을 load
# * test_sentences.xlsx에 있는 테스트 문장들을 tokenizing 후 결과 확인
#     * 특수 문자(,.-()*&^%$#@!) 제거 후 프로세스 진행

# %%
vocab_file = "./Model/kowiki_30000.model"
sp = spm.SentencePieceProcessor()
sp.load(vocab_file)
# Out:
# True

# %%
def pre_sentence(row):
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', row)
    return text

def tokenize(row):
    tokens = sp.encode_as_pieces(row['test_sentence'])
    sent = 'V'.join(tokens)
    sent = sent.replace('▁', ' ')
    return sent

df = pd.read_excel('./UserData/test_sentences.xlsx')
df['test_sentence'] = df['test_sentence'].apply(pre_sentence)
df['sentence'] = df.apply(tokenize, axis=1)
df
# Out:
#                                         test_sentence  \
# 0                         포스코케미칼 차세대 배터리 양극재 개발  매일경제
# 1   더블유게임즈의 전신은 2012년 4월 온라인 게임 및 개발 서비스를 목적으로 설립된...
# 2                     손태승 회장의 디지털 혁신 우리금융그룹 1위 도약 이끈다
# 3           HDC현대산업개발 9000억원대 서창김포 고속도로 건설 우선협상대상자 선정
# 4                         애경산업 케라시스 홍삼농축액 담은 헤어케어 선보여
# 5   GC녹십자와 셀트리온 중심으로 준비중예상보다 늦어질듯 국내에서 개발 중인 신종 코로...
# 6                            쿠쿠 아이스텐에스 정수기 판매량 126 급등
# 7                  BGF리테일 전국 CU 매장 5천여곳 폭염쉼터로 24시간 개방
# 8                                카카오 카카오페이로 해외 직구도 한다
# 9                                    오리온 케이준 눈을감자’ 출시
# 10                     넷마블 리니지2 레볼루션 확장팩 전용 캐릭터 4종 공개
# 11                  삼성바이오로직스 이뮨온시아와 면역항암제 5건 위탁 개발 계약
# 12                            동서식품 리츠 샌드위치 크래커 초코’ 출시
# 13                         LIG넥스원 이지스함 뛰어넘는 전투체계 만들 것
# 14                             이노션 센트럴시티 마케팅소통 장소로 각광
# 15                 삼성 이재용 경영승계 삼성물산 합병 찬성 국민연금 뒤늦은 반성
# 16                           만도쏘카 커넥티드카 원격진단 시스템 공동개발
# 17                     코스맥스 친환경 수성 네일 에나멜 제품 개발  한경닷컴
# 18     종근당 락토핏 생유산균 드실때 프리바이오틱스와 프로바이오틱스 둘다 챙겨 먹는게 좋다
# 19                      현대로템 이집트 카이로 전동차사업 순항2차 물량 인도
# 20                     동아에스티 완치제 없는 치매’ 줄기세포 치료제 개발한다
# 21                     한국콜마 국내 최초 기름Oil 싹 뺀 자외선차단제 개발
# 22                   신세계인터내셔날 온라인 자사몰 SI빌리지’ 매출 비중 확대
# 23                       롯데하이마트 비디오커머스 전용관 하트ON TV 오픈
# 24                    가장 젊은 이마트 등장 오는 16일 이마트 신촌점’ 오픈
# 25               BNK금융지주 하반기 마이데이터 사업 진출 코로나 시대 준비 박차
# 26                 현대위아 전기·수소차 부품 공기압축기 사업 진출미래 준비 박차
# 27                      현대홈쇼핑 온라인 전용 홈케어 브랜드 에버블루’ 런칭
# 28                       한라홀딩스 원격근무제 Work Anywhere 시행
# 29                    랭킹 1위 삼성생명 신뢰에 먹칠암 보험금 지급 거절 일쑤
# 30                                 한화생명 실속플러스 종신보험 출시
# 31                              코오롱인더 감성텐트 오두막 시리즈 출시
# 32                        락앤락 여름맞이 다이어트 도와줄 특별 기획전 마련
# 33                             한전기술 이엠솔루션과 수소기술 개발 협약
#
#                                              sentence
# 0               포V스코V케V미V칼V 차세대V 배터리V 양극V재V 개발V 매일V경제
# 1    더블V유V게임V즈의V 전V신은V 2012V년V 4V월V 온라인V 게임V 및V 개발...
# 2      손V태V승V 회V장의V 디지털V 혁신V 우리V금융V그룹V 1V위V 도V약V 이끈V다
# 3    HDVCV현대V산업V개발V 9V000V억원V대V 서V창V김V포V 고속도로V 건설V...
# 4         애V경V산업V 케V라V시스V 홍V삼V농V축V액V 담은V 헤어V케V어V 선보V여
# 5    GVCV녹V십V자와V 셀V트리V온V 중심으로V 준비V중V예V상V보다V 늦V어V질V...
# 6                 쿠V쿠V 아이스V텐V에스V 정수V기V 판매량V 12V6V 급V등
# 7    BVGVFV리V테일V 전국V CVUV 매장V 5V천여V곳V 폭V염V쉼V터로V 24...
# 8                        카카오V 카카오V페V이로V 해외V 직V구V도V 한다
# 9                             오리온V 케이V준V 눈을V감V자V’V 출시
# 10     넷V마V블V 리V니V지V2V 레V볼V루션V 확장V팩V 전용V 캐릭터V 4V종V 공개
# 11   삼성V바이V오로V직V스V 이V뮨V온V시아V와V 면역V항V암V제V 5V건V 위탁V ...
# 12                동서V식품V 리V츠V 샌드V위치V 크V래V커V 초V코V’V 출시
# 13            LVIGV넥V스V원V 이지V스V함V 뛰어넘V는V 전투V체계V 만들V 것
# 14                    이노V션V 센트럴V시티V 마케팅V소V통V 장소로V 각V광
# 15   삼성V 이재V용V 경영V승V계V 삼성V물V산V 합병V 찬성V 국민V연금V 뒤V늦V...
# 16              만V도V쏘V카V 커V넥V티드V카V 원격V진V단V 시스템V 공동V개발
# 17         코스V맥스V 친환경V 수성V 네V일V 에V나V멜V 제품V 개발V 한V경V닷컴
# 18   종V근V당V 락V토V핏V 생V유산V균V 드V실V때V 프리V바이V오V틱V스와V 프로...
# 19          현V대로V템V 이집트V 카이로V 전동차V사업V 순항V2V차V 물V량V 인도
# 20       동아V에V스티V 완V치V제V 없는V 치V매V’V 줄기세포V 치료V제V 개발V한다
# 21     한국V콜V마V 국내V 최초V 기름VOVilV 싹V V뺀V 자V외선V차V단V제V 개발
# 22   신세계V인터V내V셔V날V 온라인V 자사V몰V SVIV빌V리지V’V 매출V 비V중V 확대
# 23            롯데V하이V마트V 비디오V커V머스V 전용V관V 하트VONV TVV 오픈
# 24      가장V 젊은V 이V마트V 등장V 오는V 16V일V 이V마트V 신V촌V점V’V 오픈
# 25   BVNVKV금융V지V주V 하반V기V 마이V데이터V 사업V 진출V 코로나V 시대V ...
# 26   현대V위V아V 전기V·V수소V차V 부품V 공V기압V축V기V 사업V 진출V미래V 준...
# 27       현대V홈V쇼V핑V 온라인V 전용V 홈V케V어V 브랜드V 에버V블V루V’V 런V칭
# 28        한V라V홀V딩V스V 원격V근V무V제V WVorkV AnVyVwVhereV 시행
# 29     랭킹V 1V위V 삼성V생명V 신뢰V에V 먹V칠V암V 보험V금V 지급V 거절V 일V쑤
# 30                          한화V생명V 실V속V플러스V 종신V보험V 출시
# 31                 코V오V롱V인V더V 감V성V텐V트V 오V두V막V 시리즈V 출시
# 32           락V앤V락V 여름V맞V이V 다이어V트V 도와V줄V 특별V 기획V전V 마련
# 33                  한V전V기술V 이V엠V솔V루션V과V 수소V기술V 개발V 협약

# %% [markdown]
# ## Add words without training
# ### Environments setting
# * https://github.com/google/sentencepiece#c-from-source
#     * 위와 같이 sentencePiece 설치
#     * spm_export_vocab --model=xxx.model --output_format=vocab --output=xxx.vocab
# * sentencepiece_model_pb2.py 가져오기

# %%
# !wget "https://raw.githubusercontent.com/google/sentencepiece/master/python/sentencepiece_model_pb2.py"
# Out:
# --2020-07-20 11:23:17--  https://raw.githubusercontent.com/google/sentencepiece/master/python/sentencepiece_model_pb2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30433 (30K) [text/plain]
# Saving to: ‘sentencepiece_model_pb2.py’
#
# sentencepiece_model 100%[===================>]  29.72K  --.-KB/s    in 0.04s
#
# 2020-07-20 11:23:17 (698 KB/s) - ‘sentencepiece_model_pb2.py’ saved [30433/30433]

# %% [markdown]
# ### Words add
# * sentencepiece model proto를 통해 새로운 단어를 학습 과정 없이 model에 추가.

# %%
import sentencepiece_model_pb2 as model

m = model.ModelProto()
m.ParseFromString(open(vocab_file, 'rb').read())
# Out:
# 761836

# %%
piece_df = pd.read_excel('./UserData/user_dictionary.xlsx')
add_pieces = piece_df['add_keywords'].to_list()
len(add_pieces)
# Out:
# 34

# %%
for piece in tqdm(add_pieces, total=len(add_pieces)):
    tokens = sp.encode_as_pieces(piece)

    # 이미 사전에 등록된 키워드인 경우 별도의 추가 없이 패스
    if '▁' + piece == tokens[0]:
        continue
    
    # proto burf
    word = '▁' + piece
    piece_obj = m.pieces.add()
    piece_obj.piece = word
    piece_obj.score = -10
    piece_obj.type = m.SentencePiece.USER_DEFINED
    
    # 추가를 진행 시 vacab 사이즈가 기존 보다 클 경우 에러 발생
    # 에러가 발생하기 때문에 해당 단어의 첫 sub word를 교체하는 방식으로 진행
    for p in m.pieces:
        if p.piece == tokens[0]:
            print("origin piece - {0}, change piece - {1}".format(p.piece, word))
            p = piece

with open('./Model/new_domain.model', 'wb') as f:
    f.write(m.SerializeToString())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# origin piece - ▁포, change piece - ▁포스코케미칼
# origin piece - ▁더블, change piece - ▁더블유게임즈
# origin piece - ▁우리, change piece - ▁우리금융지주
# origin piece - ▁HD, change piece - ▁HDC현대산업개발
# origin piece - ▁애, change piece - ▁애경산업
# origin piece - ▁셀, change piece - ▁셀트리온
# origin piece - ▁쿠, change piece - ▁쿠쿠홈시스
# origin piece - ▁B, change piece - ▁BGF리테일
# origin piece - ▁넷, change piece - ▁넷마블
# origin piece - ▁삼성, change piece - ▁삼성바이오로직스
# origin piece - ▁L, change piece - ▁LIG넥스원
# origin piece - ▁이노, change piece - ▁이노션
# origin piece - ▁삼성, change piece - ▁삼성물산
# origin piece - ▁만, change piece - ▁만도
# origin piece - ▁코스, change piece - ▁코스맥스
# origin piece - ▁종, change piece - ▁종근당
# origin piece - ▁현, change piece - ▁현대로템
# origin piece - ▁동아, change piece - ▁동아에스티
# origin piece - ▁한국, change piece - ▁한국콜마
# origin piece - ▁신세계, change piece - ▁신세계인터내셔날
# origin piece - ▁롯데, change piece - ▁롯데하이마트
# origin piece - ▁이, change piece - ▁이마트
# origin piece - ▁B, change piece - ▁BNK금융지주
# origin piece - ▁현대, change piece - ▁현대위아
# origin piece - ▁현대, change piece - ▁현대홈쇼핑
# origin piece - ▁한, change piece - ▁한라홀딩스
# origin piece - ▁삼성, change piece - ▁삼성생명
# origin piece - ▁한화, change piece - ▁한화생명
# origin piece - ▁코, change piece - ▁코오롱인더
# origin piece - ▁락, change piece - ▁락앤락
# origin piece - ▁한, change piece - ▁한전기술

# %%
# !spm_export_vocab --model=./Model/new_domain.model --output_format=vocab --output=./Model/new_domain.vocab

# %% [markdown]
# ### SentencePiece Test
# * 추가된 키워드가 정상적으로 tokenizing 되는지 테스트
# * 테스트 결과 기존의 모델과 비교

# %%
vocab_file = "./new_domain.model"
sp = spm.SentencePieceProcessor()
sp.load(vocab_file)
# Out:
# True

# %%
def pre_sentence(row):
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', row)
    return text

def tokenize(row):
    tokens = sp.encode_as_pieces(row['test_sentence'])
    sent = 'V'.join(tokens)
    sent = sent.replace('▁', ' ')
    return sent

domain_df = pd.read_excel('./UserData/test_sentences.xlsx')
domain_df['test_sentence'] = domain_df['test_sentence'].apply(pre_sentence)
domain_df['domain_sentence'] = domain_df.apply(tokenize, axis=1)
domain_df
# Out:
#                                         test_sentence  \
# 0                         포스코케미칼 차세대 배터리 양극재 개발  매일경제
# 1   더블유게임즈의 전신은 2012년 4월 온라인 게임 및 개발 서비스를 목적으로 설립된...
# 2                     손태승 회장의 디지털 혁신 우리금융그룹 1위 도약 이끈다
# 3           HDC현대산업개발 9000억원대 서창김포 고속도로 건설 우선협상대상자 선정
# 4                         애경산업 케라시스 홍삼농축액 담은 헤어케어 선보여
# 5   GC녹십자와 셀트리온 중심으로 준비중예상보다 늦어질듯 국내에서 개발 중인 신종 코로...
# 6                            쿠쿠 아이스텐에스 정수기 판매량 126 급등
# 7                  BGF리테일 전국 CU 매장 5천여곳 폭염쉼터로 24시간 개방
# 8                                카카오 카카오페이로 해외 직구도 한다
# 9                                    오리온 케이준 눈을감자’ 출시
# 10                     넷마블 리니지2 레볼루션 확장팩 전용 캐릭터 4종 공개
# 11                  삼성바이오로직스 이뮨온시아와 면역항암제 5건 위탁 개발 계약
# 12                            동서식품 리츠 샌드위치 크래커 초코’ 출시
# 13                         LIG넥스원 이지스함 뛰어넘는 전투체계 만들 것
# 14                             이노션 센트럴시티 마케팅소통 장소로 각광
# 15                 삼성 이재용 경영승계 삼성물산 합병 찬성 국민연금 뒤늦은 반성
# 16                           만도쏘카 커넥티드카 원격진단 시스템 공동개발
# 17                     코스맥스 친환경 수성 네일 에나멜 제품 개발  한경닷컴
# 18     종근당 락토핏 생유산균 드실때 프리바이오틱스와 프로바이오틱스 둘다 챙겨 먹는게 좋다
# 19                      현대로템 이집트 카이로 전동차사업 순항2차 물량 인도
# 20                     동아에스티 완치제 없는 치매’ 줄기세포 치료제 개발한다
# 21                     한국콜마 국내 최초 기름Oil 싹 뺀 자외선차단제 개발
# 22                   신세계인터내셔날 온라인 자사몰 SI빌리지’ 매출 비중 확대
# 23                       롯데하이마트 비디오커머스 전용관 하트ON TV 오픈
# 24                    가장 젊은 이마트 등장 오는 16일 이마트 신촌점’ 오픈
# 25               BNK금융지주 하반기 마이데이터 사업 진출 코로나 시대 준비 박차
# 26                 현대위아 전기·수소차 부품 공기압축기 사업 진출미래 준비 박차
# 27                      현대홈쇼핑 온라인 전용 홈케어 브랜드 에버블루’ 런칭
# 28                       한라홀딩스 원격근무제 Work Anywhere 시행
# 29                    랭킹 1위 삼성생명 신뢰에 먹칠암 보험금 지급 거절 일쑤
# 30                                 한화생명 실속플러스 종신보험 출시
# 31                              코오롱인더 감성텐트 오두막 시리즈 출시
# 32                        락앤락 여름맞이 다이어트 도와줄 특별 기획전 마련
# 33                             한전기술 이엠솔루션과 수소기술 개발 협약
#
#                                       domain_sentence
# 0                   포스코케미칼V 차세대V 배터리V 양극V재V 개발V 매일V경제
# 1    더블유게임즈V의V 전V신은V 2012V년V 4V월V 온라인V 게임V 및V 개발V ...
# 2      손V태V승V 회V장의V 디지털V 혁신V 우리V금융V그룹V 1V위V 도V약V 이끈V다
# 3    HDC현대산업개발V 9V000V억원V대V 서V창V김V포V 고속도로V 건설V 우선V...
# 4           애경산업V 케V라V시스V 홍V삼V농V축V액V 담은V 헤어V케V어V 선보V여
# 5    GVCV녹V십V자와V 셀트리온V 중심으로V 준비V중V예V상V보다V 늦V어V질V듯V...
# 6                 쿠V쿠V 아이스V텐V에스V 정수V기V 판매량V 12V6V 급V등
# 7    BGF리테일V 전국V CVUV 매장V 5V천여V곳V 폭V염V쉼V터로V 24V시간V 개방
# 8                        카카오V 카카오V페V이로V 해외V 직V구V도V 한다
# 9                             오리온V 케이V준V 눈을V감V자V’V 출시
# 10       넷마블V 리V니V지V2V 레V볼V루션V 확장V팩V 전용V 캐릭터V 4V종V 공개
# 11    삼성바이오로직스V 이V뮨V온V시아V와V 면역V항V암V제V 5V건V 위탁V 개발V 계약
# 12                동서V식품V 리V츠V 샌드V위치V 크V래V커V 초V코V’V 출시
# 13                LIG넥스원V 이지V스V함V 뛰어넘V는V 전투V체계V 만들V 것
# 14                     이노션V 센트럴V시티V 마케팅V소V통V 장소로V 각V광
# 15   삼성V 이재V용V 경영V승V계V 삼성물산V 합병V 찬성V 국민V연금V 뒤V늦V은V 반성
# 16               만도V쏘V카V 커V넥V티드V카V 원격V진V단V 시스템V 공동V개발
# 17          코스맥스V 친환경V 수성V 네V일V 에V나V멜V 제품V 개발V 한V경V닷컴
# 18   종근당V 락V토V핏V 생V유산V균V 드V실V때V 프리V바이V오V틱V스와V 프로V바...
# 19            현대로템V 이집트V 카이로V 전동차V사업V 순항V2V차V 물V량V 인도
# 20         동아에스티V 완V치V제V 없는V 치V매V’V 줄기세포V 치료V제V 개발V한다
# 21       한국콜마V 국내V 최초V 기름VOVilV 싹V V뺀V 자V외선V차V단V제V 개발
# 22       신세계인터내셔날V 온라인V 자사V몰V SVIV빌V리지V’V 매출V 비V중V 확대
# 23              롯데하이마트V 비디오V커V머스V 전용V관V 하트VONV TVV 오픈
# 24        가장V 젊은V 이마트V 등장V 오는V 16V일V 이마트V 신V촌V점V’V 오픈
# 25    BNK금융지주V 하반V기V 마이V데이터V 사업V 진출V 코로나V 시대V 준비V 박V차
# 26   현대위아V 전기V·V수소V차V 부품V 공V기압V축V기V 사업V 진출V미래V 준비V...
# 27          현대홈쇼핑V 온라인V 전용V 홈V케V어V 브랜드V 에버V블V루V’V 런V칭
# 28            한라홀딩스V 원격V근V무V제V WVorkV AnVyVwVhereV 시행
# 29      랭킹V 1V위V 삼성생명V 신뢰V에V 먹V칠V암V 보험V금V 지급V 거절V 일V쑤
# 30                           한화생명V 실V속V플러스V 종신V보험V 출시
# 31                     코오롱인더V 감V성V텐V트V 오V두V막V 시리즈V 출시
# 32             락앤락V 여름V맞V이V 다이어V트V 도와V줄V 특별V 기획V전V 마련
# 33                    한전기술V 이V엠V솔V루션V과V 수소V기술V 개발V 협약

# %%
pd.merge(domain_df, df)
# Out:
#                                         test_sentence  \
# 0                         포스코케미칼 차세대 배터리 양극재 개발  매일경제
# 1   더블유게임즈의 전신은 2012년 4월 온라인 게임 및 개발 서비스를 목적으로 설립된...
# 2                     손태승 회장의 디지털 혁신 우리금융그룹 1위 도약 이끈다
# 3           HDC현대산업개발 9000억원대 서창김포 고속도로 건설 우선협상대상자 선정
# 4                         애경산업 케라시스 홍삼농축액 담은 헤어케어 선보여
# 5   GC녹십자와 셀트리온 중심으로 준비중예상보다 늦어질듯 국내에서 개발 중인 신종 코로...
# 6                            쿠쿠 아이스텐에스 정수기 판매량 126 급등
# 7                  BGF리테일 전국 CU 매장 5천여곳 폭염쉼터로 24시간 개방
# 8                                카카오 카카오페이로 해외 직구도 한다
# 9                                    오리온 케이준 눈을감자’ 출시
# 10                     넷마블 리니지2 레볼루션 확장팩 전용 캐릭터 4종 공개
# 11                  삼성바이오로직스 이뮨온시아와 면역항암제 5건 위탁 개발 계약
# 12                            동서식품 리츠 샌드위치 크래커 초코’ 출시
# 13                         LIG넥스원 이지스함 뛰어넘는 전투체계 만들 것
# 14                             이노션 센트럴시티 마케팅소통 장소로 각광
# 15                 삼성 이재용 경영승계 삼성물산 합병 찬성 국민연금 뒤늦은 반성
# 16                           만도쏘카 커넥티드카 원격진단 시스템 공동개발
# 17                     코스맥스 친환경 수성 네일 에나멜 제품 개발  한경닷컴
# 18     종근당 락토핏 생유산균 드실때 프리바이오틱스와 프로바이오틱스 둘다 챙겨 먹는게 좋다
# 19                      현대로템 이집트 카이로 전동차사업 순항2차 물량 인도
# 20                     동아에스티 완치제 없는 치매’ 줄기세포 치료제 개발한다
# 21                     한국콜마 국내 최초 기름Oil 싹 뺀 자외선차단제 개발
# 22                   신세계인터내셔날 온라인 자사몰 SI빌리지’ 매출 비중 확대
# 23                       롯데하이마트 비디오커머스 전용관 하트ON TV 오픈
# 24                    가장 젊은 이마트 등장 오는 16일 이마트 신촌점’ 오픈
# 25               BNK금융지주 하반기 마이데이터 사업 진출 코로나 시대 준비 박차
# 26                 현대위아 전기·수소차 부품 공기압축기 사업 진출미래 준비 박차
# 27                      현대홈쇼핑 온라인 전용 홈케어 브랜드 에버블루’ 런칭
# 28                       한라홀딩스 원격근무제 Work Anywhere 시행
# 29                    랭킹 1위 삼성생명 신뢰에 먹칠암 보험금 지급 거절 일쑤
# 30                                 한화생명 실속플러스 종신보험 출시
# 31                              코오롱인더 감성텐트 오두막 시리즈 출시
# 32                        락앤락 여름맞이 다이어트 도와줄 특별 기획전 마련
# 33                             한전기술 이엠솔루션과 수소기술 개발 협약
#
#                                       domain_sentence  \
# 0                   포스코케미칼V 차세대V 배터리V 양극V재V 개발V 매일V경제
# 1    더블유게임즈V의V 전V신은V 2012V년V 4V월V 온라인V 게임V 및V 개발V ...
# 2      손V태V승V 회V장의V 디지털V 혁신V 우리V금융V그룹V 1V위V 도V약V 이끈V다
# 3    HDC현대산업개발V 9V000V억원V대V 서V창V김V포V 고속도로V 건설V 우선V...
# 4           애경산업V 케V라V시스V 홍V삼V농V축V액V 담은V 헤어V케V어V 선보V여
# 5    GVCV녹V십V자와V 셀트리온V 중심으로V 준비V중V예V상V보다V 늦V어V질V듯V...
# 6                 쿠V쿠V 아이스V텐V에스V 정수V기V 판매량V 12V6V 급V등
# 7    BGF리테일V 전국V CVUV 매장V 5V천여V곳V 폭V염V쉼V터로V 24V시간V 개방
# 8                        카카오V 카카오V페V이로V 해외V 직V구V도V 한다
# 9                             오리온V 케이V준V 눈을V감V자V’V 출시
# 10       넷마블V 리V니V지V2V 레V볼V루션V 확장V팩V 전용V 캐릭터V 4V종V 공개
# 11    삼성바이오로직스V 이V뮨V온V시아V와V 면역V항V암V제V 5V건V 위탁V 개발V 계약
# 12                동서V식품V 리V츠V 샌드V위치V 크V래V커V 초V코V’V 출시
# 13                LIG넥스원V 이지V스V함V 뛰어넘V는V 전투V체계V 만들V 것
# 14                     이노션V 센트럴V시티V 마케팅V소V통V 장소로V 각V광
# 15   삼성V 이재V용V 경영V승V계V 삼성물산V 합병V 찬성V 국민V연금V 뒤V늦V은V 반성
# 16               만도V쏘V카V 커V넥V티드V카V 원격V진V단V 시스템V 공동V개발
# 17          코스맥스V 친환경V 수성V 네V일V 에V나V멜V 제품V 개발V 한V경V닷컴
# 18   종근당V 락V토V핏V 생V유산V균V 드V실V때V 프리V바이V오V틱V스와V 프로V바...
# 19            현대로템V 이집트V 카이로V 전동차V사업V 순항V2V차V 물V량V 인도
# 20         동아에스티V 완V치V제V 없는V 치V매V’V 줄기세포V 치료V제V 개발V한다
# 21       한국콜마V 국내V 최초V 기름VOVilV 싹V V뺀V 자V외선V차V단V제V 개발
# 22       신세계인터내셔날V 온라인V 자사V몰V SVIV빌V리지V’V 매출V 비V중V 확대
# 23              롯데하이마트V 비디오V커V머스V 전용V관V 하트VONV TVV 오픈
# 24        가장V 젊은V 이마트V 등장V 오는V 16V일V 이마트V 신V촌V점V’V 오픈
# 25    BNK금융지주V 하반V기V 마이V데이터V 사업V 진출V 코로나V 시대V 준비V 박V차
# 26   현대위아V 전기V·V수소V차V 부품V 공V기압V축V기V 사업V 진출V미래V 준비V...
# 27          현대홈쇼핑V 온라인V 전용V 홈V케V어V 브랜드V 에버V블V루V’V 런V칭
# 28            한라홀딩스V 원격V근V무V제V WVorkV AnVyVwVhereV 시행
# 29      랭킹V 1V위V 삼성생명V 신뢰V에V 먹V칠V암V 보험V금V 지급V 거절V 일V쑤
# 30                           한화생명V 실V속V플러스V 종신V보험V 출시
# 31                     코오롱인더V 감V성V텐V트V 오V두V막V 시리즈V 출시
# 32             락앤락V 여름V맞V이V 다이어V트V 도와V줄V 특별V 기획V전V 마련
# 33                    한전기술V 이V엠V솔V루션V과V 수소V기술V 개발V 협약
#
#                                              sentence
# 0               포V스코V케V미V칼V 차세대V 배터리V 양극V재V 개발V 매일V경제
# 1    더블V유V게임V즈의V 전V신은V 2012V년V 4V월V 온라인V 게임V 및V 개발...
# 2      손V태V승V 회V장의V 디지털V 혁신V 우리V금융V그룹V 1V위V 도V약V 이끈V다
# 3    HDVCV현대V산업V개발V 9V000V억원V대V 서V창V김V포V 고속도로V 건설V...
# 4         애V경V산업V 케V라V시스V 홍V삼V농V축V액V 담은V 헤어V케V어V 선보V여
# 5    GVCV녹V십V자와V 셀V트리V온V 중심으로V 준비V중V예V상V보다V 늦V어V질V...
# 6                 쿠V쿠V 아이스V텐V에스V 정수V기V 판매량V 12V6V 급V등
# 7    BVGVFV리V테일V 전국V CVUV 매장V 5V천여V곳V 폭V염V쉼V터로V 24...
# 8                        카카오V 카카오V페V이로V 해외V 직V구V도V 한다
# 9                             오리온V 케이V준V 눈을V감V자V’V 출시
# 10     넷V마V블V 리V니V지V2V 레V볼V루션V 확장V팩V 전용V 캐릭터V 4V종V 공개
# 11   삼성V바이V오로V직V스V 이V뮨V온V시아V와V 면역V항V암V제V 5V건V 위탁V ...
# 12                동서V식품V 리V츠V 샌드V위치V 크V래V커V 초V코V’V 출시
# 13            LVIGV넥V스V원V 이지V스V함V 뛰어넘V는V 전투V체계V 만들V 것
# 14                    이노V션V 센트럴V시티V 마케팅V소V통V 장소로V 각V광
# 15   삼성V 이재V용V 경영V승V계V 삼성V물V산V 합병V 찬성V 국민V연금V 뒤V늦V...
# 16              만V도V쏘V카V 커V넥V티드V카V 원격V진V단V 시스템V 공동V개발
# 17         코스V맥스V 친환경V 수성V 네V일V 에V나V멜V 제품V 개발V 한V경V닷컴
# 18   종V근V당V 락V토V핏V 생V유산V균V 드V실V때V 프리V바이V오V틱V스와V 프로...
# 19          현V대로V템V 이집트V 카이로V 전동차V사업V 순항V2V차V 물V량V 인도
# 20       동아V에V스티V 완V치V제V 없는V 치V매V’V 줄기세포V 치료V제V 개발V한다
# 21     한국V콜V마V 국내V 최초V 기름VOVilV 싹V V뺀V 자V외선V차V단V제V 개발
# 22   신세계V인터V내V셔V날V 온라인V 자사V몰V SVIV빌V리지V’V 매출V 비V중V 확대
# 23            롯데V하이V마트V 비디오V커V머스V 전용V관V 하트VONV TVV 오픈
# 24      가장V 젊은V 이V마트V 등장V 오는V 16V일V 이V마트V 신V촌V점V’V 오픈
# 25   BVNVKV금융V지V주V 하반V기V 마이V데이터V 사업V 진출V 코로나V 시대V ...
# 26   현대V위V아V 전기V·V수소V차V 부품V 공V기압V축V기V 사업V 진출V미래V 준...
# 27       현대V홈V쇼V핑V 온라인V 전용V 홈V케V어V 브랜드V 에버V블V루V’V 런V칭
# 28        한V라V홀V딩V스V 원격V근V무V제V WVorkV AnVyVwVhereV 시행
# 29     랭킹V 1V위V 삼성V생명V 신뢰V에V 먹V칠V암V 보험V금V 지급V 거절V 일V쑤
# 30                          한화V생명V 실V속V플러스V 종신V보험V 출시
# 31                 코V오V롱V인V더V 감V성V텐V트V 오V두V막V 시리즈V 출시
# 32           락V앤V락V 여름V맞V이V 다이어V트V 도와V줄V 특별V 기획V전V 마련
# 33                  한V전V기술V 이V엠V솔V루션V과V 수소V기술V 개발V 협약
